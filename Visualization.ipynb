# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.hist(df['Log Growth Rate'], bins=30)
plt.xlabel('Log Growth Rate')
plt.ylabel('Frequency')
plt.title('Histogram of Log Growth Rate')
plt.show()

plt.hist(df['Growth Rate'], bins=30)
plt.xlabel('Growth Rate')
plt.ylabel('Frequency')
plt.title('Histogram of Growth Rate')
plt.show()
